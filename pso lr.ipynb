# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from lib.utils import *
d = pd.read_csv('bank_notes.csv',encoding='latin1')
ac=[]
IMAGE_SIZE = [224, 224]
train_path = 'Train'
df = pd.DataFrame(d)

# %%
df.head()
# Out:
#    variance  skewness  curtosis  entropy  Target
# 0   3.62160    8.6661   -2.8073 -0.44699       0
# 1   4.54590    8.1674   -2.4586 -1.46210       0
# 2   3.86600   -2.6383    1.9242  0.10645       0
# 3   3.45660    9.5228   -4.0112 -3.59440       0
# 4   0.32924   -4.4552    4.5718 -0.98880       0

# %%
import cv2
import glob
cv_img = plt.imread('Train\Tennote\\1.jpg')
plt.imshow(cv_img)

# %%
import cv2
import glob
cv_img = plt.imread('Train\Twentynote\\1.jpg')
plt.imshow(cv_img)

# %%
sns.countplot(x='Target',data=df)
# Out:
# <AxesSubplot:xlabel='Target', ylabel='count'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1372 entries, 0 to 1371
# Data columns (total 5 columns):
# variance    1372 non-null float64
# skewness    1372 non-null float64
# curtosis    1372 non-null float64
# entropy     1372 non-null float64
# Target      1372 non-null int64
# dtypes: float64(4), int64(1)
# memory usage: 53.7 KB

# %%
df.describe()
# Out:
#           variance     skewness     curtosis      entropy       Target
# count  1372.000000  1372.000000  1372.000000  1372.000000  1372.000000
# mean      0.433735     1.922353     1.397627    -1.191657     0.444606
# std       2.842763     5.869047     4.310030     2.101013     0.497103
# min      -7.042100   -13.773100    -5.286100    -8.548200     0.000000
# 25%      -1.773000    -1.708200    -1.574975    -2.413450     0.000000
# 50%       0.496180     2.319650     0.616630    -0.586650     0.000000
# 75%       2.821475     6.814625     3.179250     0.394810     1.000000
# max       6.824800    12.951600    17.927400     2.449500     1.000000

# %%
sns.barplot(x='Target',y='variance',data=df,hue='Target')
# Out:
# <AxesSubplot:xlabel='Target', ylabel='variance'>

# %%
sns.boxplot(x='Target',y='variance',data=df,hue='Target')
# Out:
# <AxesSubplot:xlabel='Target', ylabel='variance'>

# %%
sns.jointplot(x='Target',y='variance',data=df)#,hue='Target')

# %%
sns.stripplot(x='Target',y='variance',data=df,hue='Target')
# Out:
# <AxesSubplot:xlabel='Target', ylabel='variance'>

# %%
sns.boxplot(x='Target',y='skewness',data=df,hue='Target')
# Out:
# <AxesSubplot:xlabel='Target', ylabel='skewness'>

# %%
sns.boxplot(x='Target',y='curtosis',data=df,hue='Target')
# Out:
# <AxesSubplot:xlabel='Target', ylabel='curtosis'>

# %%
sns.boxplot(x='Target',y='entropy',data=df,hue='Target')
# Out:
# <AxesSubplot:xlabel='Target', ylabel='entropy'>

# %%
heatmp = df.corr()
sns.heatmap(heatmp,annot=True)
# Out:
# <AxesSubplot:>

# %%
#sns.clustermap(df)

# %%
sns.distplot(df.variance)
# Out:
# C:\Users\kumar\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='variance', ylabel='Density'>

# %%
sns.distplot(df.curtosis)
# Out:
# C:\Users\kumar\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='curtosis', ylabel='Density'>

# %%
sns.distplot(df.entropy)
# Out:
# C:\Users\kumar\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='entropy', ylabel='Density'>

# %%
sns.pairplot(df,hue='Target')

# %%
df['Target'].value_counts()
# Out:
# 0    762
# 1    610
# Name: Target, dtype: int64

# %%
df.head()
# Out:
#    variance  skewness  curtosis  entropy  Target
# 0   3.62160    8.6661   -2.8073 -0.44699       0
# 1   4.54590    8.1674   -2.4586 -1.46210       0
# 2   3.86600   -2.6383    1.9242  0.10645       0
# 3   3.45660    9.5228   -4.0112 -3.59440       0
# 4   0.32924   -4.4552    4.5718 -0.98880       0

# %%
y=df['Target']
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Target, dtype: int64

# %%
X=df.drop('Target',axis=1)

# %%
feat = pd.DataFrame(X)

# %%
feat.head()
# Out:
#    variance  skewness  curtosis  entropy
# 0   3.62160    8.6661   -2.8073 -0.44699
# 1   4.54590    8.1674   -2.4586 -1.46210
# 2   3.86600   -2.6383    1.9242  0.10645
# 3   3.45660    9.5228   -4.0112 -3.59440
# 4   0.32924   -4.4552    4.5718 -0.98880

# %%
feat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1372 entries, 0 to 1371
# Data columns (total 4 columns):
# variance    1372 non-null float64
# skewness    1372 non-null float64
# curtosis    1372 non-null float64
# entropy     1372 non-null float64
# dtypes: float64(4)
# memory usage: 43.0 KB

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=3)
pca.fit(X)
x_pca= pca.transform(X)
x_pca.shape
plt.figure(figsize=(10,6))
plt.scatter(x_pca[:,0],x_pca[:,0],c=y,cmap='plasma')
plt.xlabel('First PC')
plt.ylabel('second PC')
# Out:
# Text(0, 0.5, 'second PC')

# %%
df_comp = pd.DataFrame(pca.components_,columns=list(X))
plt.figure(figsize=(10,8))
sns.heatmap(df_comp,cmap='plasma')
# Out:
# <AxesSubplot:>

# %%
pca = PCA().fit(X)

plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Variance (%)') 
plt.title('Bank Note Variance Explained')
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(feat, y, test_size=0.30,stratify=y )

# %%
from sklearn import linear_model
model= linear_model.Lasso(alpha=0.1)
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
ac.append(accuracy_score(y_pred,y_test,sample_weight=0.4)*100)

# %%
model=pso()
m=model.fit(X_train,y_train)
model=m.predict(X_test)
ac.append(accuracy_score(model,y_test,sample_weight=1)*100)

# %%
import numpy as np
import seaborn as sns
import matplotlib as plt

plt.style.use('dark_background')
x=['PSO','Lasso regression']
ac.reverse() 
ax=sns.barplot(x,ac[:2])
ax.set_title('Accuracy comparison')
ax.set_ylabel('Accuracy')
#ax.yaxis.set_major_locator(ticker.LinearLocator())
print("the accuracy of {} is {} and {} is {}".format(x[0],ac[0],x[1],ac[1]))
ax.set_ylim(50,100)
# Out:
# the accuracy of PSO is 94.3 and Lasso regression is 93.92
# C:\Users\kumar\AppData\Local\Programs\Python\Python36\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# (50.0, 100.0)
